# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/hand_landmarks_dataset.csv")

# %%
df
# Out:
#             x0        y0        x1        y1        x2        y2        x3  \
# 0     0.761977  1.132745  0.718180  1.103303  0.695195  1.046915  0.693597
# 1     0.744771  1.077719  0.694525  1.040790  0.655600  0.975359  0.629975
# 2     0.741646  1.015747  0.687772  0.974313  0.644994  0.910991  0.617092
# 3     0.736060  0.976401  0.682355  0.936291  0.639388  0.869252  0.608612
# 4     0.726309  0.943744  0.673784  0.906735  0.631296  0.843946  0.597933
# ...        ...       ...       ...       ...       ...       ...       ...
# 2689  0.496458  0.616493  0.529678  0.728817  0.568544  0.819822  0.609503
# 2690  0.481460  0.648323  0.510362  0.760050  0.552425  0.855791  0.592187
# 2691  0.456413  0.688967  0.487241  0.802296  0.528923  0.895111  0.565430
# 2692  0.434560  0.761202  0.460970  0.871358  0.498642  0.958917  0.526427
# 2693  0.416128  0.890247  0.460971  1.007245  0.516265  1.033355  0.568398
#
#             y3        x4        y4  ...       y16       x17       y17  \
# 0     1.012111  0.695445  0.980653  ...  0.704026  0.843952  0.972672
# 1     0.916366  0.597355  0.881457  ...  0.611424  0.823071  0.884702
# 2     0.855660  0.589252  0.826998  ...  0.556179  0.808437  0.811824
# 3     0.817156  0.578677  0.795445  ...  0.514518  0.787812  0.764725
# 4     0.794963  0.566537  0.773783  ...  0.499074  0.771467  0.737925
# ...        ...       ...       ...  ...       ...       ...       ...
# 2689  0.896399  0.634957  0.954022  ...  0.612725  0.616208  0.542197
# 2690  0.931838  0.619268  0.988092  ...  0.639215  0.599642  0.559569
# 2691  0.968122  0.587992  1.027204  ...  0.677643  0.580051  0.596887
# 2692  1.029015  0.536842  1.089136  ...  0.751448  0.563252  0.664998
# 2693  0.984791  0.593331  0.927835  ...  0.883624  0.554583  0.778956
#
#            x18       y18       x19       y19       x20       y20      label
# 0     0.883814  0.916779  0.905635  0.870731  0.923925  0.817802  Open-hand
# 1     0.858645  0.822626  0.881255  0.778147  0.899942  0.735036  Open-hand
# 2     0.841138  0.752118  0.859475  0.710059  0.873507  0.669469  Open-hand
# 3     0.818159  0.704225  0.836589  0.661309  0.852136  0.618209  Open-hand
# 4     0.801333  0.676532  0.820184  0.635126  0.835906  0.593970  Open-hand
# ...        ...       ...       ...       ...       ...       ...        ...
# 2689  0.650545  0.541683  0.616326  0.560734  0.597515  0.571710    Dislike
# 2690  0.633678  0.562509  0.596610  0.582608  0.578445  0.591559    Dislike
# 2691  0.615049  0.601106  0.577516  0.622010  0.558367  0.627371    Dislike
# 2692  0.598769  0.671833  0.560243  0.692295  0.541829  0.693820    Dislike
# 2693  0.594531  0.820290  0.552890  0.839315  0.523820  0.824790    Dislike
#
# [2694 rows x 43 columns]

# %%
import numpy as np
import ast

# %%
# Normalize relative to wrist position (x0, y0)
normalized_df = df.copy()

for idx, row in df.iterrows():
    wrist_x = row["x0"]  # Wrist x coordinate
    wrist_y = row["y0"]  # Wrist y coordinate

    # Normalize all x and y coordinates relative to wrist
    for i in range(21):  # Assuming 21 landmarks (0-20)
        x_col = f"x{i}"
        y_col = f"y{i}"

        if x_col in df.columns and y_col in df.columns:
            normalized_df.loc[idx, x_col] = row[x_col] - wrist_x
            normalized_df.loc[idx, y_col] = row[y_col] - wrist_y

# %%
normalized_df.to_csv(
    "../data/hand_landmarks_dataset_normalized_to_the_wrist.csv", index=False
)
